# %%
import pandas as pd
import numpy as np
from gensim.models import Word2Vec
from sklearn.cluster import KMeans

# %%
word_vectors = Word2Vec.load("../processing/word2vec.model").wv

# %%
model = KMeans(n_clusters=2, max_iter=1000, random_state=True, n_init=60).fit(X=word_vectors.vectors.astype('double'))

# %%
word_vectors.similar_by_vector(model.cluster_centers_[1], topn=10, restrict_vocab=None)
# Out:
# [('attempt', 0.999849259853363),
#  ('being_connected', 0.9998491406440735),
#  ('wonderful_evening', 0.9998481869697571),
#  ('nothing_like', 0.9998468160629272),
#  ('embodiment', 0.9998446702957153),
#  ('i_chatted', 0.9998445510864258),
#  ('protective_equipment', 0.9998411536216736),
#  ('chabua', 0.9998408555984497),
#  ('elephant', 0.9998398423194885),
#  ('engage_with', 0.9998378157615662)]

# %%
p_cluster_index = 1
p_cluster_center = model.cluster_centers_[p_cluster_index]
n_cluster_center = model.cluster_centers_[1-p_cluster_index]

# %%
words = pd.DataFrame(word_vectors.index_to_key)
words.columns = ['words']
words.head(10)
words['vectors'] = words.words.apply(lambda x: word_vectors[f'{x}'])
words['cluster'] = words.vectors.apply(lambda x: model.predict([np.array(x)]))
words.cluster = words.cluster.apply(lambda x: x[0])

# %%
words['cluster_value'] = [1 if i==p_cluster_index else -1 for i in words.cluster]
words['closeness_score'] = words.apply(lambda x: 1/(model.transform([x.vectors]).min()), axis = 1)
words['sentiment_coeff'] = words.closeness_score * words.cluster_value

# %%
words.head(20)
# Out:
#     words                                            vectors  cluster  \
# 0     the  [-0.0032557384, 0.014657231, 0.044013068, 0.01...        1
# 1      to  [-0.023520468, 0.054787725, 0.033953186, 0.022...        1
# 2     and  [-0.019750055, 0.043906864, 0.03623085, 0.0173...        1
# 3      of  [0.0027759434, 0.014083014, 0.04596995, 0.0122...        1
# 4      in  [-0.0070596556, 0.018992692, 0.042874303, 0.00...        1
# 5       a  [-0.027137583, 0.043569054, 0.04206904, 0.0163...        1
# 6     for  [-0.0183038, 0.043328803, 0.03902246, 0.014244...        1
# 7      we  [-0.017228326, 0.0498171, 0.037371643, 0.01505...        1
# 8      is  [-0.019295039, 0.035370808, 0.044744648, 0.011...        1
# 9     our  [-0.024284206, 0.051811915, 0.032582283, 0.017...        1
# 10   with  [-0.026202185, 0.047049437, 0.045883518, 0.019...        1
# 11   that  [-0.017454954, 0.042195108, 0.03672094, 0.0122...        1
# 12     on  [-0.03282982, 0.05087515, 0.040996917, 0.02727...        1
# 13   this  [-0.018788662, 0.04752572, 0.037295397, 0.0118...        1
# 14   will  [-0.021404438, 0.047364585, 0.03943629, 0.0080...        1
# 15     it  [-0.014529489, 0.043457016, 0.04089403, 0.0110...        1
# 16      i  [-0.012996893, 0.04146651, 0.04796274, 0.01651...        1
# 17    are  [-0.014724436, 0.048083335, 0.048587635, 0.012...        1
# 18  today  [-0.01991878, 0.038352247, 0.042055763, 0.0134...        1
# 19    all  [-0.012673461, 0.04782677, 0.043612525, 0.0149...        1
#
#     cluster_value  closeness_score  sentiment_coeff
# 0               1         4.886942         4.886942
# 1               1         5.927927         5.927927
# 2               1         7.065258         7.065258
# 3               1         4.435699         4.435699
# 4               1         7.980787         7.980787
# 5               1        11.548194        11.548194
# 6               1        12.321323        12.321323
# 7               1         6.645021         6.645021
# 8               1        10.826874        10.826874
# 9               1         7.177469         7.177469
# 10              1        12.682765        12.682765
# 11              1         8.740166         8.740166
# 12              1         9.059839         9.059839
# 13              1        11.808346        11.808346
# 14              1         9.722811         9.722811
# 15              1         9.450832         9.450832
# 16              1        11.148761        11.148761
# 17              1        11.726491        11.726491
# 18              1        20.539350        20.539350
# 19              1        12.024268        12.024268

# %%
words[['words', 'sentiment_coeff']].to_csv('sentiment_dictionary.csv', index = False)
